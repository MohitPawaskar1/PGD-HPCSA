# %%
import pandas as pd
from sklearn.datasets import load_digits
from sklearn.svm import SVC

# %%
df = pd.DataFrame(load_digits, columns=load_digits.fea)

# %%
digits = load_digits()
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']
