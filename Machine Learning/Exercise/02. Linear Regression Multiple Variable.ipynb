# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from word2number import w2n

# %%
df = pd.read_csv(r'/home/acts/Mohit/PGD-HPCSA/Machine Learning/Datasets/hiring.csv')
df.head()
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000

# %%
for i in range(8):
    print(w2n.word_to_num(df.experience[i]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 for i in range(8):
# ----> 2     print(w2n.word_to_num(df.experience[i]))
#
# File ~/.local/lib/python3.12/site-packages/word2number/w2n.py:134, in word_to_num(number_sentence)
#     132 def word_to_num(number_sentence):
#     133     if type(number_sentence) is not str:
# --> 134         raise ValueError("Type of input is not string! Please enter a valid number word (eg. \'two million twenty three thousand and forty nine\')")
#     136     number_sentence = number_sentence.replace('-', ' ')
#     137     number_sentence = number_sentence.lower()  # converting input to lowercase
#
# ValueError: Type of input is not string! Please enter a valid number word (eg. 'two million twenty three thousand and forty nine')

# %%
df.count()
# Out:
# experience                    6
# test_score(out of 10)         7
# interview_score(out of 10)    8
# salary($)                     8
# dtype: int64

# %%
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000
